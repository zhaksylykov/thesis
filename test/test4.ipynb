# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %%
import train 
import data_utils
# Out:
# ---------------------------------------------------------------------------
# DuplicateFlagError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import train
#       2 import data_utils
#
# File ~\thesis\NJODE\train.py:29
#      27 from configs import config
#      28 import models
# ---> 29 import data_utils
#      31 # Use absolute imports
#      32 #from NJODE import data_utils
#      33 #from NJODE.configs import config
#      34 #import NJODE.models as models
#      35 sys.path.append("../")
#
# File ~\thesis\NJODE\data_utils.py:27
#      25 # =====================================================================================================================
#      26 FLAGS = flags.FLAGS
# ---> 27 flags.DEFINE_string("dataset_params", None,
#      28                     "name of the dict with data hyper-params")
#      29 flags.DEFINE_string("dataset_name", None,
#      30                     "name of the dataset to generate")
#      31 flags.DEFINE_integer("seed", 0,
#      32                      "seed for making dataset generation reproducible")
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\absl\flags\_defines.py:417, in DEFINE_string(name, default, help, flag_values, required, **args)
#     415 parser = _argument_parser.ArgumentParser[str]()
#     416 serializer = _argument_parser.ArgumentSerializer[str]()
# --> 417 return DEFINE(
#     418     parser,
#     419     name,
#     420     default,
#     421     help,
#     422     flag_values,
#     423     serializer,
#     424     required=True if required else False,
#     425     **args,
#     426 )
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\absl\flags\_defines.py:124, in DEFINE(parser, name, default, help, flag_values, serializer, module_name, required, **args)
#      89 def DEFINE(  # pylint: disable=invalid-name
#      90     parser,
#      91     name,
#    (...)
#      97     required=False,
#      98     **args):
#      99   """Registers a generic Flag object.
#     100
#     101   NOTE: in the docstrings of all DEFINE* functions, "registers" is short
#    (...)
#     122     a handle to defined flag.
#     123   """
# --> 124   return DEFINE_flag(
#     125       _flag.Flag(parser, serializer, name, default, help, **args),
#     126       flag_values,
#     127       module_name,
#     128       required=True if required else False,
#     129   )
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\absl\flags\_defines.py:183, in DEFINE_flag(flag, flag_values, module_name, required)
#     181 # Copying the reference to flag_values prevents pychecker warnings.
#     182 fv = flag_values
# --> 183 fv[flag.name] = flag
#     184 # Tell flag_values who's defining the flag.
#     185 if module_name:
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\absl\flags\_flagvalues.py:449, in FlagValues.__setitem__(self, name, flag)
#     443   if (self.find_module_defining_flag(name) == module_name and
#     444       id(module) != self.find_module_id_defining_flag(name)):
#     445     # If the flag has already been defined by a module with the same name,
#     446     # but a different ID, we can stop here because it indicates that the
#     447     # module is simply being imported a subsequent time.
#     448     return
# --> 449   raise _exceptions.DuplicateFlagError.from_flag(name, self)
#     450 # If a new flag overrides an old one, we need to cleanup the old flag's
#     451 # modules if it's not registered.
#     452 flags_to_cleanup = set()
#
# DuplicateFlagError: The flag 'dataset_params' is defined twice. First from NJODE.data_utils, Second from data_utils.  Description from first occurrence: name of the dict with data hyper-params

# %%
dataset_dic = {
    'drift': np.array([0.5, 0.5, 0.5]).tolist(),
    'volatility': np.array([[0.2, 0.1, 0.1], [0.1, 0.2, 0.1], [0.1,0.1, 0.2]]).tolist(),
    'mean': np.array([0.5, 0.5, 0.5]).tolist(),
    'poisson_lambda': 3.0,
    'speed': np.array([[0.3, 0.0, 0.0], [0.0, 0.4, 0.0],[0.0,0.0,0.5]]).tolist(),
    'correlation': 0.5,
    'nb_paths': 300,
    'nb_steps': 100,
    'S0': np.array([1.0, 1.5 ,2.0]).tolist(),
    'maturity': 1.0,
    'dimension': 3,
    'obs_perc': 1.0,
    'scheme': 'euler',
    'return_vol': False,
    'v0': 1,
    'hurst': 0.75,
    'FBMmethod': 'daviesharte',
    'model_name': 'OrnsteinUhlenbeckWithCrossTerms',
    'dt': 0.01
}

# %%
datasetpath, dataset_id = data_util.create_dataset("OrnsteinUhlenbeckWithCrossTerms",dataset_dic)

# %%
dataset_id
# Out:
# 30

# %%
dataset_metadata = data_util.load_metadata(stock_model_name="OrnsteinUhlenbeckWithCrossTerms",time_id=30)

# %%
dataset_metadata["dimension"]
# Out:
# 3

# %%
train.train(dataset="OrnsteinUhlenbeckWithCrossTerms", dataset_id=30, data_dict=dataset_dic, use_cond_exp = False)

# %%
from models import NJODE
checkpoint = torch.load("../data/saved_models/id-20/best_checkpoint/checkpt.tar")
state_dict=checkpoint['model_state_dict']

# %%
state_dict
# Out:
# OrderedDict([('ode_f.f.0.weight',
#               tensor([[-4.6704e-02,  7.2204e-02, -6.2405e-02,  ..., -7.8976e-03,
#                         3.3973e-02,  7.3963e-03],
#                       [-1.4619e-02, -4.0299e-02,  2.2504e-02,  ..., -3.4302e-02,
#                        -3.6700e-03, -5.6320e-02],
#                       [ 1.9629e-02,  2.2321e-02, -2.4921e-02,  ...,  1.8087e-02,
#                         3.9124e-03, -1.8601e-05],
#                       ...,
#                       [ 6.8489e-02,  6.8699e-02,  3.7755e-02,  ...,  3.0108e-03,
#                         7.9594e-03, -5.2973e-02],
#                       [-1.7247e-02,  4.2316e-02, -1.2825e-02,  ..., -2.7936e-02,
#                        -7.3024e-03, -1.5222e-02],
#                       [-1.5287e-02, -1.9622e-02, -7.2343e-02,  ..., -5.9798e-03,
#                        -4.6128e-03, -4.7666e-09]])),
#              ('ode_f.f.0.bias',
#               tensor([-0.0348, -0.0119,  0.0237, -0.0226,  0.0337,  0.0263, -0.0170,  0.0350,
#                        0.0254,  0.0169, -0.0332,  0.0343, -0.0361, -0.0203, -0.0164, -0.0431,
#                        0.0320, -0.0208, -0.0114,  0.0138,  0.0241,  0.0075, -0.0247,  0.0342,
#                       -0.0274,  0.0096, -0.0037, -0.0249,  0.0162,  0.0241, -0.0254, -0.0255,
#                        0.0330, -0.0174,  0.0243, -0.0237,  0.0124, -0.0348,  0.0246,  0.0235,
#                        0.0237,  0.0193, -0.0002,  0.0060, -0.0340, -0.0118, -0.0153,  0.0315,
#                       -0.0351, -0.0204])),
#              ('ode_f.f.3.weight',
#               tensor([[ 0.0053, -0.0115, -0.0287,  ...,  0.0531,  0.0351,  0.0654],
#                         0.0690,  0.0179],
#                       [ 0.2120, -0.0504,  0.1466,  0.2948, -0.2103, -0.0737, -0.3102,  0.0553,
#                        -0.0262,  0.2477],
#                       [ 0.0323, -0.4091, -0.0199, -0.4021,  0.1344,  0.2026,  0.1230,  0.2201,
#                         0.1236, -0.0564],
#                       [ 0.0614, -0.0163, -0.2044,  0.3501, -0.2769,  0.2957, -0.1835, -0.1538,
#                        -0.0593, -0.1733],
#                       [ 0.2253, -0.0174,  0.1854,  0.0168,  0.0985,  0.1167, -0.3386, -0.1494,
#                        -0.0918, -0.0654],
#                       [-0.0562,  0.1477,  0.0236, -0.1288,  0.1600, -0.0664, -0.3088,  0.2778,
#                         0.0702, -0.1754],
#                       [ 0.1664, -0.2658,  0.1128, -0.0822,  0.2628, -0.2790, -0.2614,  0.3141,
#                        -0.0540, -0.0241],
#                       [-0.2245,  0.2664,  0.1357, -0.2871, -0.0024,  0.0057,  0.2243,  0.0747,
#                        -0.1790,  0.0175],
#                       [ 0.2486, -0.0281, -0.2470, -0.0858, -0.2536,  0.1127, -0.0126, -0.0851,
#                         0.2687, -0.1613],
#                       [-0.1008,  0.1727, -0.1820,  0.1980,  0.2729, -0.1770, -0.2889, -0.0568,
#                         0.1977,  0.1304],
#                       [-0.2754,  0.0845,  0.1431, -0.1801, -0.1309, -0.0659,  0.2146, -0.0548,
#                         0.1265, -0.0795],
#                       [ 0.2055, -0.0807,  0.0941, -0.1112, -0.0224,  0.2782, -0.1695, -0.2685,
#                         0.0369,  0.2512],
#                       [-0.2094, -0.1027,  0.0674,  0.0898,  0.0353,  0.1722,  0.0347,  0.0068,
#                        -0.0191, -0.0957],
#                       [ 0.0793,  0.1367, -0.1454, -0.0260,  0.1025,  0.1871,  0.1895, -0.1244,
#                         0.0596, -0.2128],
#                       [ 0.0244, -0.2501,  0.2372, -0.0882,  0.0843, -0.0870, -0.0208,  0.0099,
#                         0.1285,  0.1599],
#                       [ 0.1669,  0.0558,  0.2371, -0.2169, -0.2545,  0.0308,  0.2612,  0.0991,
#                        -0.2659, -0.0980],
#                       [ 0.2953, -0.0374, -0.0499,  0.0924,  0.2460, -0.1901, -0.0101, -0.0208,
#                        -0.1628,  0.1827],
#                       [ 0.1367,  0.0563, -0.3342, -0.0956,  0.0754, -0.0293,  0.0711,  0.2354,
#                        -0.0669,  0.0909],
#                       [ 0.0258,  0.0104, -0.0985, -0.1510,  0.0017,  0.2565,  0.0547, -0.1113,
#                        -0.1669, -0.0879],
#                       [ 0.1461, -0.0009,  0.0410, -0.1924, -0.2653,  0.0326, -0.0139,  0.3522,
#                        -0.2493, -0.1006],
#                       [ 0.2636, -0.3341,  0.0923,  0.0440, -0.2779, -0.0748, -0.0682,  0.1876,
#                         0.2890, -0.1014],
#                       [-0.2182,  0.1991,  0.0839, -0.0644, -0.1211, -0.3462,  0.1888,  0.2363,
#                         0.2205, -0.1008],
#                       [ 0.2065, -0.0668,  0.1368, -0.0277,  0.1585,  0.1374, -0.1714, -0.2153,
#                        -0.2153,  0.2655],
#                       [ 0.2704,  0.1212, -0.2521,  0.0384, -0.0103, -0.0710, -0.0171,  0.0850,
#                         0.1112, -0.2312],
#                       [ 0.2342, -0.1161, -0.1139, -0.1689, -0.1252, -0.1459,  0.3254,  0.1883,
#                        -0.1016, -0.2507],
#                       [-0.2459, -0.1325,  0.1974,  0.3613,  0.0536, -0.1999,  0.0425, -0.2095,
#                         0.0051, -0.1228],
#                       [-0.1543,  0.0068, -0.0368, -0.2067, -0.2257,  0.0319,  0.1504,  0.0395,
#                         0.1440,  0.1909],
#                       [-0.3514, -0.0325,  0.2189, -0.3209,  0.2556,  0.2182,  0.0909, -0.0596,
#                        -0.0631, -0.0757],
#                       [ 0.0193,  0.1156,  0.1997,  0.1373,  0.1780,  0.1509, -0.0830,  0.1404,
#                         0.1102,  0.0421],
#                       [-0.1329, -0.0063,  0.1580,  0.1137,  0.1427, -0.2955, -0.2429,  0.2505,
#                        -0.0397,  0.1329],
#                       [ 0.0927,  0.2883, -0.0910, -0.0897, -0.1924, -0.1510, -0.2911,  0.2426,
#                         0.0418,  0.1528],
#                       [ 0.1348, -0.2704,  0.1777, -0.1592, -0.1745, -0.0237,  0.0615,  0.2124,
#                        -0.0296, -0.0726],
#                       [-0.2519,  0.2389, -0.1531,  0.0577, -0.0884, -0.1885,  0.1709,  0.1502,
#                         0.1562, -0.3157],
#                       [ 0.1738, -0.3077,  0.2174, -0.1622,  0.2960,  0.1551, -0.2109, -0.0025,
#                        -0.1165, -0.3014],
#                       [-0.2652,  0.2425, -0.0218,  0.2146, -0.0723, -0.1582,  0.0819, -0.0416,
#                        -0.0096, -0.1815],
#                       [-0.0440, -0.0262,  0.0242,  0.2143,  0.2111, -0.0570,  0.0332, -0.0716,
#                        -0.2490, -0.0735],
#                       [ 0.0931,  0.1375,  0.1742, -0.1740,  0.0533, -0.2740, -0.1282,  0.1886,
#                        -0.0803, -0.1945],
#                       [-0.0718,  0.0032,  0.1141, -0.3546, -0.0344,  0.1861, -0.1627,  0.2663,
#                        -0.0438,  0.2708],
#                       [-0.0885, -0.2255,  0.0928,  0.2202, -0.1567,  0.1881, -0.0008,  0.2743,
#                        -0.2756, -0.2345],
#                       [-0.1355,  0.3045, -0.0817, -0.0420, -0.0833,  0.1871, -0.2837, -0.1527,
#                         0.0705,  0.1759],
#                       [ 0.0833, -0.2511,  0.1386,  0.0028,  0.0223, -0.2016,  0.1507, -0.0107,
#                         0.0983, -0.1704],
#                       [ 0.2384, -0.1120,  0.2198, -0.0616, -0.0036,  0.0102,  0.2192, -0.3099,
#                        -0.0030, -0.2124]])),
#              ('readout_map.ffnn.0.bias',
#               tensor([-0.0385, -0.0072,  0.0707, -0.0328,  0.0536, -0.0658,  0.0531,  0.0531,
#                       -0.0932, -0.0128, -0.0925,  0.0380, -0.0368, -0.0272,  0.0298, -0.0330,
#                        0.0466, -0.0426,  0.0165,  0.0148, -0.0745, -0.1009, -0.0304, -0.0547,
#                       -0.0241, -0.0395,  0.0602,  0.0364, -0.0216, -0.0389,  0.0558, -0.0326,
#                        0.0435,  0.0798,  0.0799, -0.0324, -0.1031,  0.0152,  0.0293, -0.0225,
#                       -0.0180, -0.0198,  0.0047,  0.0131,  0.0203, -0.0458,  0.0059,  0.0243,
#                       -0.0034, -0.0607])),
#              ('readout_map.ffnn.3.weight',
#               tensor([[ 0.0491, -0.1923, -0.0955,  ..., -0.0029,  0.0761,  0.0696],
#                       [ 0.1064,  0.1196,  0.0982,  ..., -0.0131,  0.0769, -0.1833],
#                       [-0.2191,  0.1193, -0.2061,  ...,  0.0948,  0.0630, -0.1879],
#                       ...,
#                       [-0.0610, -0.0289,  0.0682,  ...,  0.1418,  0.1946, -0.1077],
#                       [-0.0427,  0.0313, -0.2349,  ..., -0.2157,  0.0912,  0.1666],
#                       [ 0.1829, -0.0486,  0.0070,  ...,  0.0717, -0.0067, -0.0900]])),
#              ('readout_map.ffnn.3.bias',
#               tensor([-0.0632,  0.0112, -0.0260, -0.0064,  0.0070,  0.0199,  0.0326,  0.0152,
#                        0.0439,  0.0012,  0.0135, -0.0335,  0.0159, -0.0203, -0.0207, -0.0137,
#                        0.0105, -0.0018,  0.0132, -0.0121,  0.0581, -0.0039,  0.0275, -0.0077,
#                        0.0106, -0.0307, -0.0136, -0.0216, -0.0355,  0.0043,  0.0141,  0.0108,
#                        0.0508,  0.0312,  0.0065, -0.0057, -0.0274, -0.0012,  0.0098,  0.0159,
#                        0.0306,  0.0171, -0.0293,  0.0249, -0.0038,  0.0067,  0.0188,  0.0036,
#                        0.0095, -0.0156])),
#              ('readout_map.ffnn.6.weight',
#               tensor([[ 0.1785, -0.2145,  0.0866, -0.0392,  0.0259,  0.1288,  0.2154, -0.2387,
#                        -0.0013,  0.1490, -0.1760,  0.1250,  0.0789, -0.1910,  0.0373,  0.1801,
#                        -0.1119,  0.2055, -0.0708, -0.0125,  0.2056,  0.2956,  0.0825,  0.2024,
#                         0.2755,  0.0874, -0.2306,  0.0372,  0.2485, -0.2982,  0.0696, -0.0764,
#                         0.1670, -0.2208, -0.2454,  0.1318, -0.0123,  0.0652,  0.0839, -0.1825,
#                        -0.1787,  0.1817,  0.1637, -0.0570, -0.0715,  0.1338, -0.0408, -0.1922,
#                        -0.2621,  0.1657],
#                       [-0.1186,  0.2175, -0.0212,  0.0252,  0.0484, -0.2666,  0.1682, -0.0939,
#                        -0.0206, -0.1151,  0.0970, -0.1729, -0.0613, -0.1561, -0.2669,  0.1233,
#                         0.2884, -0.0030, -0.2705,  0.2870,  0.1744,  0.1905, -0.0998, -0.1572,
#                         0.2524, -0.1680,  0.0621,  0.1484,  0.0773, -0.0495, -0.0043, -0.0490,
#                        -0.1070,  0.1157, -0.1032,  0.2360,  0.1976,  0.3006,  0.2382,  0.2792,
#                        -0.3227, -0.2424, -0.1767, -0.1847, -0.1000, -0.1309, -0.1029, -0.2145,
#                        -0.0476,  0.2222],
#                         0.1653, -0.1605, -0.0424, -0.2047, -0.1571,  0.0059, -0.2407,  0.2515,
#                        -0.1664, -0.0403, -0.0920,  0.2061,  0.0158,  0.1868,  0.0457,  0.0855,
#                        -0.1632, -0.0628],
#                       [ 0.1069, -0.0560, -0.0376,  0.1928,  0.1754,  0.0530,  0.0791,  0.2112,
#                         0.0612,  0.0299,  0.1731,  0.0177, -0.0412,  0.2451, -0.0483, -0.0976,
#                         0.0608,  0.1299,  0.1923,  0.1723, -0.0698, -0.2861, -0.1886, -0.0277,
#                        -0.0750,  0.0675,  0.1961, -0.0935, -0.1538,  0.0646,  0.0372, -0.1579,
#                         0.1242, -0.2403,  0.1011, -0.2361,  0.0696, -0.1204, -0.2436, -0.0111,
#                         0.1680, -0.0016,  0.0568, -0.0683,  0.1820, -0.1698, -0.2195,  0.0070,
#                        -0.1570,  0.1621],
#                       [ 0.1127,  0.2109, -0.1723, -0.0136, -0.0380,  0.0462,  0.0840,  0.1077,
#                        -0.1296,  0.0537,  0.0129, -0.1987,  0.1530, -0.1447, -0.1000, -0.1694,
#                        -0.0904, -0.0028, -0.0214,  0.1473,  0.1738, -0.2343, -0.0011,  0.1832,
#                         0.0913, -0.0724,  0.2242,  0.2901,  0.2201, -0.0588, -0.2279, -0.0161,
#                        -0.0727,  0.0572,  0.1376, -0.1190, -0.1428, -0.2720, -0.0811, -0.1986,
#                        -0.1369, -0.0247,  0.0610,  0.1790,  0.1985,  0.0877,  0.0309,  0.1796,
#                        -0.2169,  0.2263]])),
#              ('readout_map.ffnn.6.bias',
#               tensor([-0.0078,  0.0173,  0.0083,  0.0049,  0.0009,  0.0100,  0.0112,  0.0109,
#                        0.0120]))])

# %%
options = {'options': {'which_loss': 'standard'}}

# %%
ode_nn=((50, "tanh"), (50, "tanh"))
readout_nn=((50, "tanh"), (50, "tanh"))
enc_nn=((50, "tanh"), (50, "tanh"))

# %%
params_dict = {  # create a dictionary of the wanted parameters
    'input_size': 9, 'epochs': 100,'hidden_size': 10, 'output_size': 9,
    'ode_nn': ode_nn, 'readout_nn': readout_nn, 'enc_nn': enc_nn,
    'use_rnn': False,
    'options': options, "input_coords":np.arange(9), "output_coords":np.arange(9)
}

# %%
model=NJODE(**params_dict)
# Out:
# using loss: standard
# neuralODE use input scaling with tanh
# use residual network: input_size=9, output_size=10
# use residual network: input_size=10, output_size=9

# %%
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
times=[]
time_ptr = [0]
obs_idx = []
delta_t=0.01
T=0.01
X= torch.empty(9,9)
start_X= torch.tensor([[1.0], [1.5], [2.0], [1.0], [1.5**2], [4.0], [1.5], [2.0],[3.0]]).reshape(1,9)
n_obs_ot=torch.empty((1,1))

# %%
prediction=model.get_pred(times, time_ptr, X, obs_idx, delta_t, T, start_X, n_obs_ot)
prediction["pred"].size()
# Out:
# torch.Size([101, 1, 9])

# %%
start_X[:, :3]
# Out:
# tensor([[1.0000, 1.5000, 2.0000]])

# %%
prediction["pred"][1, :, :3]
# Out:
# tensor([[1.0021, 1.5033, 1.9849]], grad_fn=<SliceBackward0>)

# %%
def get_mu_hat(times,time_ptr,obs_idx,delta_t,T,X,start_X, n_obs_ot, d):
    njode_pred=model.get_pred(times, time_ptr, X, obs_idx, delta_t, T, start_X, n_obs_ot)["pred"]
    mu=(njode_pred[-1,:,:d]-start_X[:,:d])/delta_t
    return mu

# %%
def construct_matrix(output, d):
    XX = torch.zeros((d, d), dtype=output.dtype)

    for i in range(d):
        XX[i, i] = output[:,d + i]

    index = 2 * d
    for i in range(d):
        for j in range(i + 1, d):
            XX[i, j] = output[:,index]
            XX[j, i] = output[:,index]
            index += 1

    return XX

# %%
def get_sigma_hat(times,time_ptr,obs_idx,delta_t,T,X,start_X, n_obs_ot,d):
    X0=start_X[:, :d]
    njode_pred=model.get_pred(times, time_ptr, X, obs_idx, delta_t, T, start_X, n_obs_ot)["pred"]
    sig1=(construct_matrix(njode_pred[-1,:],d)-construct_matrix(start_X,d))/delta_t
    mu = get_mu_hat(times,time_ptr,obs_idx,delta_t,T,X,start_X, n_obs_ot,d)
    sig2=X0.T@mu+mu.T@X0
    return sig1-sig2

# %%
mu=get_mu_hat(times,time_ptr,obs_idx,delta_t,T,X,start_X, n_obs_ot, 3)

# %%
mu
# Out:
# tensor([[ 0.2109,  0.3317, -1.5054]], grad_fn=<DivBackward0>)

# %%
sigma=get_sigma_hat(times,time_ptr,obs_idx,delta_t,T,X,start_X, n_obs_ot,3)

# %%
sigma
# Out:
# tensor([[-0.4218, -0.6480,  1.0836],
#         [-0.6480, -0.9950,  1.5947],
#         [ 1.0836,  1.5947,  6.0214]], grad_fn=<NegBackward0>)

# %%
x=sigma.detach().numpy()

# %%
np.linalg.eigvals(x)
# Out:
# array([ 6.4914680e+00,  3.3932055e-16, -1.8868544e+00], dtype=float32)

# %%
 np.linalg.cholesky(x)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 np.linalg.cholesky(x)
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\numpy\linalg\linalg.py:779, in cholesky(a)
#     777 t, result_t = _commonType(a)
#     778 signature = 'D->D' if isComplexType(t) else 'd->d'
# --> 779 r = gufunc(a, signature=signature, extobj=extobj)
#     780 return wrap(r.astype(result_t, copy=False))
#
# File C:\Program Files\Miniconda3\envs\thesis\lib\site-packages\numpy\linalg\linalg.py:115, in _raise_linalgerror_nonposdef(err, flag)
#     114 def _raise_linalgerror_nonposdef(err, flag):
# --> 115     raise LinAlgError("Matrix is not positive definite")
#
# LinAlgError: Matrix is not positive definite

# %%
input=construct_matrix(start_X,3)

# %%
input
# Out:
# tensor([[1.0000, 1.5000, 2.0000],
#         [1.5000, 2.2500, 3.0000],
#         [2.0000, 3.0000, 4.0000]])

# %%
input=input.detach().numpy()

# %%
np.linalg.eigvals(input)
# Out:
# array([0.  , 7.25, 0.  ], dtype=float32)

# %%
njode_pred=model.get_pred(times, time_ptr, X, obs_idx, delta_t, 0.5, start_X, n_obs_ot)["pred"]
output=construct_matrix(njode_pred[-1,:],3)
